# %% [markdown]
# ## 0. Download dataset
# **Note:** If you can't download using gdown due to limited number of downloads, please download it manually and upload it to your drive, then copy it from the drive to colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/1F6kUoxIeDbc_oQO2ADtyIetzQkRdIc0r/view?usp=share_link
# !gdown --id 1F6kUoxIeDbc_oQO2ADtyIetzQkRdIc0r

# %% [markdown]
# ## 1. Import libraries

# %%
import torch
import torch.nn as nn

seed = 1
torch.manual_seed(seed)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ## 2. Read dataset

# %%
dataset_filepath = 'dataset/weatherHistory.csv'
df = pd.read_csv(dataset_filepath)

# %%
univariate_df = df['Temperature (C)']
univariate_df.index = df['Formatted Date']

# %%
univariate_df
# Out:
# Formatted Date
# 2006-04-01 00:00:00.000 +0200     9.472222
# 2006-04-01 01:00:00.000 +0200     9.355556
# 2006-04-01 02:00:00.000 +0200     9.377778
# 2006-04-01 03:00:00.000 +0200     8.288889
# 2006-04-01 04:00:00.000 +0200     8.755556
#                                    ...
# 2016-09-09 19:00:00.000 +0200    26.016667
# 2016-09-09 20:00:00.000 +0200    24.583333
# 2016-09-09 21:00:00.000 +0200    22.038889
# 2016-09-09 22:00:00.000 +0200    21.522222
# 2016-09-09 23:00:00.000 +0200    20.438889
# Name: Temperature (C), Length: 96453, dtype: float64

# %% [markdown]
# ## 3. Data preprocessing

# %%
input_size = 6 
label_size = 1 
offset = 1 

def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset):
    features = []
    labels = []

    window_size = input_size + offset

    if df_end_idx == None:
        df_end_idx = len(df) - window_size
        
    for idx in range(df_start_idx, df_end_idx):
        feature_end_idx = idx + input_size
        label_start_idx = idx + window_size - label_size

        feature = df[idx:feature_end_idx]
        label = df[label_start_idx:(idx+window_size)]

        features.append(feature)
        labels.append(label)
        
    features = np.expand_dims(np.array(features), -1)
    labels = np.array(labels)

    return features, labels

# %% [markdown]
# ## 4. Train, val, test split

# %%
dataset_length = len(univariate_df)
train_size = 0.7
val_size = 0.2
train_end_idx = int(train_size * dataset_length)
val_end_idx = int(val_size * dataset_length) + train_end_idx

X_train, y_train = slicing_window(
    univariate_df, 
    df_start_idx=0,
    df_end_idx=train_end_idx,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

X_val, y_val = slicing_window(
    univariate_df, 
    df_start_idx=train_end_idx,
    df_end_idx=val_end_idx,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

X_test, y_test = slicing_window(
    univariate_df, 
    df_start_idx=val_end_idx,
    df_end_idx=None,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

# %% [markdown]
# ## 5. Implement PyTorch dataset

# %%
class WeatherForecast(Dataset):
    def __init__(
        self,
        X, y,
        transform=None
    ):
        self.X = X
        self.y = y
        self.transform = transform
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        X = self.X[idx]
        y = self.y[idx]
        
        if self.transform:
            X = self.transform(X) 
            
        X = torch.tensor(X, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.float32)
        
        return X, y

# %% [markdown]
# ## 6. Create dataloader

# %%
train_dataset = WeatherForecast(
    X_train, y_train
)
val_dataset = WeatherForecast(
    X_val, y_val
)
test_dataset = WeatherForecast(
    X_test, y_test
)

# %%
train_batch_size = 128
test_batch_size = 8

train_loader = DataLoader(
    train_dataset,
    batch_size=train_batch_size,
    shuffle=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=test_batch_size,
    shuffle=False
)
test_loader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False
)

# %% [markdown]
# ## 7. Implement model

# %%
class WeatherForecastor(nn.Module):
    def __init__(
        self, embedding_dim, hidden_size, 
        n_layers, dropout_prob
    ):
        super(WeatherForecastor, self).__init__()
        self.lstm = nn.LSTM(embedding_dim, hidden_size, n_layers, batch_first=True)
        self.norm = nn.LayerNorm(hidden_size)
        
        self.dropout = nn.Dropout(dropout_prob) 
        self.fc = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        x, (hn, cn) = self.lstm(x)
        x = x[:, -1, :]
        x = self.norm(x)
        x = self.dropout(x)
        x = self.fc(x)
        
        return x

# %%
embedding_dim = 1
hidden_size = 8
n_layers = 3
dropout_prob = 0.2
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = WeatherForecastor(
    embedding_dim=embedding_dim,
    hidden_size=hidden_size,
    n_layers=n_layers,
    dropout_prob=dropout_prob
).to(device)

# %%
model.eval()

dummy_tensor = torch.randn((1, 6, 1)).to(device)

with torch.no_grad():
    output = model(dummy_tensor)

print('Output shape:', output.shape)
# Out:
# Output shape: torch.Size([1, 1])

# %% [markdown]
# ## 8. Training

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    
    losses = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            losses.append(loss.item())

    loss = sum(losses) / len(losses)

    return loss

# %%
def fit(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs
):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        batch_train_losses = []

        model.train()
        for idx, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            batch_train_losses.append(loss.item())

        train_loss = sum(batch_train_losses) / len(batch_train_losses)
        train_losses.append(train_loss)

        val_loss = evaluate(
            model, val_loader,
            criterion, device
        )
        val_losses.append(val_loss)

        print(f'EPOCH {epoch + 1}:\tTrain loss: {train_loss:.4f}\tVal loss: {val_loss:.4f}')

    return train_losses, val_losses

# %%
lr = 1e-3
epochs = 50

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=lr
)

# %%
train_losses, val_losses = fit(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs
)
# Out:
# EPOCH 1:	Train loss: 136.2500	Val loss: 46.9897
# EPOCH 2:	Train loss: 30.0496	Val loss: 6.8018
# EPOCH 3:	Train loss: 13.0501	Val loss: 2.8492
# EPOCH 4:	Train loss: 10.9733	Val loss: 2.3117
# EPOCH 5:	Train loss: 10.1403	Val loss: 1.7668
# EPOCH 6:	Train loss: 9.9436	Val loss: 2.1073
# EPOCH 7:	Train loss: 9.5379	Val loss: 1.5947
# EPOCH 8:	Train loss: 9.3160	Val loss: 1.8239
# EPOCH 9:	Train loss: 9.1482	Val loss: 1.6520
# EPOCH 10:	Train loss: 9.0329	Val loss: 1.5531
# EPOCH 11:	Train loss: 8.8706	Val loss: 1.5226
# EPOCH 12:	Train loss: 8.7030	Val loss: 1.8112
# EPOCH 13:	Train loss: 8.4296	Val loss: 1.7230
# EPOCH 14:	Train loss: 8.2426	Val loss: 1.5675
# EPOCH 15:	Train loss: 7.9762	Val loss: 1.6860
# EPOCH 16:	Train loss: 7.8116	Val loss: 1.7384
# EPOCH 17:	Train loss: 7.5840	Val loss: 1.8228
# EPOCH 18:	Train loss: 7.5063	Val loss: 1.5751
# EPOCH 19:	Train loss: 7.3665	Val loss: 1.6528
# EPOCH 20:	Train loss: 7.2341	Val loss: 1.5023
# EPOCH 21:	Train loss: 7.0476	Val loss: 1.7629
# EPOCH 22:	Train loss: 6.8797	Val loss: 1.6245
# EPOCH 23:	Train loss: 6.8751	Val loss: 1.4804
# EPOCH 24:	Train loss: 6.7255	Val loss: 1.5651
# EPOCH 25:	Train loss: 6.5553	Val loss: 1.6214
# EPOCH 26:	Train loss: 6.5388	Val loss: 1.6673
# EPOCH 27:	Train loss: 6.3853	Val loss: 1.5080
# EPOCH 28:	Train loss: 6.2841	Val loss: 1.6956
# EPOCH 29:	Train loss: 6.2215	Val loss: 1.4599
# EPOCH 30:	Train loss: 6.1646	Val loss: 1.5810
# EPOCH 31:	Train loss: 6.1010	Val loss: 1.4853
# EPOCH 32:	Train loss: 6.0954	Val loss: 1.5689
# EPOCH 33:	Train loss: 6.0478	Val loss: 1.5356
# EPOCH 34:	Train loss: 5.9289	Val loss: 1.5071
# EPOCH 35:	Train loss: 5.8503	Val loss: 1.8493
# EPOCH 36:	Train loss: 5.8252	Val loss: 1.6840
# EPOCH 37:	Train loss: 5.8077	Val loss: 1.8457
# EPOCH 38:	Train loss: 5.7884	Val loss: 1.5663
# EPOCH 39:	Train loss: 5.7408	Val loss: 1.4881
# EPOCH 40:	Train loss: 5.7205	Val loss: 1.6282
# EPOCH 41:	Train loss: 5.7100	Val loss: 1.4704
# EPOCH 42:	Train loss: 5.6659	Val loss: 1.4915
# EPOCH 43:	Train loss: 5.6808	Val loss: 1.5809
# EPOCH 44:	Train loss: 5.5805	Val loss: 1.4723
# EPOCH 45:	Train loss: 5.6139	Val loss: 1.5299
# EPOCH 46:	Train loss: 5.5535	Val loss: 1.4221
# EPOCH 47:	Train loss: 5.5479	Val loss: 1.4493
# EPOCH 48:	Train loss: 5.5178	Val loss: 1.5658
# EPOCH 49:	Train loss: 5.5191	Val loss: 1.4629
# EPOCH 50:	Train loss: 5.4543	Val loss: 1.4423

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(train_losses)
ax[0].set_title('Training Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[1].plot(val_losses, color='orange')
ax[1].set_title('Val Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
plt.show()

# %% [markdown]
# ## 9. Evaluation

# %%
val_loss = evaluate(
    model,
    val_loader,
    criterion,
    device
)
test_loss = evaluate(
    model,
    test_loader,
    criterion,
    device
)

print('Evaluation on val/test dataset')
print('Val loss: ', val_loss)
print('Test loss: ', test_loss)
# Out:
# Evaluation on val/test dataset
# Val loss:  1.4422877304295347
# Test loss:  1.2473008077522099

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Temperature in every hours')
    plt.xlabel('Hour')
    plt.ylabel('Temperature (C)')
    plt.legend()
    plt.show()
    
inputs = torch.tensor(X_test[:100], dtype=torch.float32).to(device)
model.eval()
with torch.no_grad():
    outputs = model(inputs).detach().cpu().numpy()
plot_difference(y_test[:100], outputs)
